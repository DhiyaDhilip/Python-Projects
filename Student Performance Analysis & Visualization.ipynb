# %%
# 🔹 Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 🔹 Load Dataset
data = pd.read_csv(r"D:/Data Sets/student_performance.csv")
print(data.head())
print("Columns:", data.columns.tolist())
print("Shape:", data.shape)
data.dtypes
data.info()
data.describe()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A
# Columns: ['student_id', 'weekly_self_study_hours', 'attendance_percentage', 'class_participation', 'total_score', 'grade']
# Shape: (1000000, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count    Dtype
# ...

# %%
data.isnull().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
# Histogram – Self Study Hours
plt.hist(data['weekly_self_study_hours'], bins=5, color='skyblue', edgecolor='black')
plt.title("Weekly Self Study Hours")
plt.xlabel("Hours")
plt.ylabel("Count")
plt.show()

# %%
# Boxplot – Total Score by Grade
sns.boxplot(x='grade', y='total_score', data=data, palette='Set2')
plt.title("Total Score by Grade")
plt.xlabel("Grade")
plt.ylabel("Score")
plt.show()
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_9664\2489878938.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='grade', y='total_score', data=data, palette='Set2')

# %%
# Bar Chart – Average Score by Grade
grade_avg = data.groupby('grade')['total_score'].mean()
plt.bar(grade_avg.index, grade_avg.values, color='orange', edgecolor='black')
plt.title("Average Score by Grade")
plt.xlabel("Grade")
plt.ylabel("Average Score")
plt.show()

# %%
# Pie Chart – Grade Distribution
grade_counts = data['grade'].value_counts()
plt.pie(grade_counts, labels=grade_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Grade Distribution")
plt.show()

# %%
# Scatter Plot – Attendance vs Total Score
plt.scatter(data['attendance_percentage'], data['total_score'], color='purple', alpha=0.6)
plt.title("Attendance vs Total Score")
plt.xlabel("Attendance (%)")
plt.ylabel("Total Score")
plt.show()

# %%
# Heatmap – Correlation
corr_cols = data[['weekly_self_study_hours', 'attendance_percentage', 'class_participation', 'total_score']]
sns.heatmap(corr_cols.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()
